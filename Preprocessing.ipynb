# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train= pd.read_csv('training.csv')
test= pd.read_csv('test.csv')

# %% [markdown]
# # Preprocessing (Training)

# %%
train_clean=train.copy()

# %%
print("number of duplicates: ",train_clean.duplicated().sum())
# Out:
# number of duplicates:  0

# %%
# initial removal of columns I deem unnecesarry

train_clean=train_clean.drop(["education_less_highschool", "education_highschool","education_some_college","education_bachelors",
                              "education_graduate","education_college_or_above","education_stem_degree","married","divorced",
                              "never_married","widowed", "age_median"], axis=1)

# %%
# adjust the age ranges 


# defining bins and labels for age ranges
age_bins = [0, 19, 39, 59, 69, float('inf')]  # Define bins
age_labels = ['19 and Under', '20-39', '40-59', '60-69', 'Over 70']

train_clean['age_group'] = pd.cut(train_clean['patient_age'], bins=age_bins, labels=age_labels, right=True)
age_dummies = pd.get_dummies(train_clean['age_group'], prefix='age')

train_clean = pd.concat([train_clean, age_dummies], axis=1)

print(train_clean[['patient_age'] + list(age_dummies.columns)].head())
# Out:
#    patient_age  age_19 and Under  age_20-39  age_40-59  age_60-69  age_Over 70
# 0           84             False      False      False      False         True
# 1           62             False      False      False       True        False
# 2           43             False      False       True      False        False
# 3           45             False      False       True      False        False
# 4           55             False      False       True      False        False

# %%
# Replacing missing values in patient_race column with 'prefer not to answer'

train_clean['patient_race'] = train_clean['patient_race'].fillna('Prefer Not to Answer')

print(train_clean['patient_race'].value_counts())
# Out:
# patient_race
# Prefer Not to Answer    6385
# White                   3588
# Black                   1056
# Hispanic                 829
# Other                    683
# Asian                    365
# Name: count, dtype: int64

# %%
#plot BMI to see what it looks like before editing

plt.hist(train_clean['bmi'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
# BMI

# Grouping by age, race, and location to compute the mean BMI for each subgroup
## This will hopefully eliminate biases in the data (fingers crossed)

bmi_means = train_clean.groupby(['age_group', 'patient_race', 'patient_state'])['bmi'].mean().reset_index()
bmi_means.rename(columns={'bmi': 'mean_bmi'}, inplace=True)

train_clean = train_clean.merge(bmi_means, on=['age_group', 'patient_race', 'patient_state'], how='left')

train_clean['bmi'] = train_clean['bmi'].fillna(train_clean['mean_bmi'])


print(train_clean['bmi'].describe())
# Out:
# count    12458.000000
# mean        28.955193
# std          3.733892
# min         14.000000
# 25%         27.239167
# 50%         28.606875
# 75%         30.431250
# max         85.000000
# Name: bmi, dtype: float64

# %%
#plot BMI to see what it looks like after editing

plt.hist(train_clean['bmi'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of BMI')
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.grid(axis='y')
plt.show()

# %%
unique_payer_types = train_clean['payer_type'].unique()
print("Unique values in 'payer_type':", unique_payer_types)
# Out:
# Unique values in 'payer_type': ['MEDICAID' 'COMMERCIAL' 'MEDICARE ADVANTAGE' nan]

# %%
# Replacing missing values in payer_type column with 'prefer not to answer'

train_clean['payer_type'] = train_clean['payer_type'].fillna('Prefer Not to Answer')

print(train_clean['payer_type'].value_counts())
# Out:
# payer_type
# COMMERCIAL              6032
# MEDICAID                2569
# MEDICARE ADVANTAGE      2502
# Prefer Not to Answer    1803
# Name: count, dtype: int64

# %%
# One-hot encode the 'payer_type' column
train_clean = pd.get_dummies(train_clean, columns=['payer_type'], drop_first=True)

# %%
# One-hot encode the 'patient_state' column
train_clean = pd.get_dummies(train_clean, columns=['patient_state'], drop_first=True)

# %%
# Create a new feature of the locations for the cancers
import re

def categorize_location(description):
    if re.search(r'upper-outer quadrant', description, re.IGNORECASE):
        return 'Upper-Outer Quadrant'
    elif re.search(r'upper-inner quadrant', description, re.IGNORECASE):
        return 'Upper-Inner Quadrant'
    elif re.search(r'lower-outer quadrant', description, re.IGNORECASE):
        return 'Lower-Outer Quadrant'
    elif re.search(r'lower-inner quadrant', description, re.IGNORECASE):
        return 'Lower-Inner Quadrant'
    elif re.search(r'axillary tail', description, re.IGNORECASE):
        return 'Axillary Tail'
    elif re.search(r'nipple and areola', description, re.IGNORECASE):
        return 'Nipple and Areola'
    elif re.search(r'central portion', description, re.IGNORECASE):
        return 'Central Portion'
    elif re.search(r'overlapping sites', description, re.IGNORECASE):
        return 'Overlapping Sites'
    elif re.search(r'unspecified site', description, re.IGNORECASE):
        return 'Unspecified Site'
    elif re.search(r'secondary malignant neoplasm', description, re.IGNORECASE):
        return 'Secondary Malignant Neoplasm'
    elif re.search(r'breast', description, re.IGNORECASE):
        return 'General Breast Cancer'
    else:
        return 'Other'

train_clean['location_category'] = train_clean['breast_cancer_diagnosis_desc'].apply(categorize_location)

print(train_clean[['breast_cancer_diagnosis_desc', 'location_category']].head())
# Out:
#                         breast_cancer_diagnosis_desc      location_category
# 0  Malignant neoplasm of unsp site of unspecified...  General Breast Cancer
# 1  Malig neoplm of upper-outer quadrant of right ...   Upper-Outer Quadrant
# 2  Malignant neoplasm of central portion of left ...        Central Portion
# 3  Malig neoplasm of upper-inner quadrant of left...   Upper-Inner Quadrant
# 4  Malignant neoplasm of breast (female), unspeci...  General Breast Cancer

# %%
# One-hot encode the 'location_category' column
train_clean = pd.get_dummies(train_clean, columns=['location_category'], drop_first=True)

# %%
# Drop the unnecesary columns
train_clean.drop(columns=['mean_bmi','breast_cancer_diagnosis_desc','age_group','age_under_10','age_10_to_19','age_20s','age_30s',
                         'age_30s','age_40s','age_50s','age_60s','age_70s','age_over_80','patient_age','patient_race',
                         'patient_gender','breast_cancer_diagnosis_code','breast_cancer_diagnosis_code',
                          'metastatic_cancer_diagnosis_code','metastatic_first_novel_treatment','metastatic_first_novel_treatment_type',
                         'Region','Division','labor_force_participation','unemployment_rate','self_employed','farmer','payer_type_MEDICAID','payer_type_MEDICARE ADVANTAGE','payer_type_Prefer Not to Answer','family_size'], inplace=True)

# %%
# drop rows from all columns that now have less than 500 missing values
columns_to_drop_missing = train_clean.columns[train_clean.isnull().sum() < 500]

train_clean = train_clean.dropna(subset=columns_to_drop_missing)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
print(train_clean.isnull().sum())
# Out:
# patient_id                                        0
# patient_zip3                                      0
# bmi                                               0
# population                                        0
# density                                           0
# male                                              0
# female                                            0
# family_dual_income                                0
# income_household_median                           0
# income_household_under_5                          0
# income_household_5_to_10                          0
# income_household_10_to_15                         0
# income_household_15_to_20                         0
# income_household_20_to_25                         0
# income_household_25_to_35                         0
# income_household_35_to_50                         0
# income_household_50_to_75                         0
# income_household_75_to_100                        0
# income_household_100_to_150                       0
# income_household_150_over                         0
# income_household_six_figure                       0
# income_individual_median                          0
# home_ownership                                    0
# housing_units                                     0
# home_value                                        0
# rent_median                                       0
# rent_burden                                       0
# race_white                                        0
# race_black                                        0
# race_asian                                        0
# race_native                                       0
# race_pacific                                      0
# race_other                                        0
# race_multiple                                     0
# hispanic                                          0
# disabled                                          0
# poverty                                           0
# limited_english                                   0
# commute_time                                      0
# health_uninsured                                  0
# veteran                                           0
# Ozone                                             0
# PM25                                              0
# N02                                               0
# DiagPeriodL90D                                    0
# age_19 and Under                                  0
# age_20-39                                         0
# age_40-59                                         0
# age_60-69                                         0
# age_Over 70                                       0
# patient_state_AL                                  0
# patient_state_AR                                  0
# patient_state_AZ                                  0
# patient_state_CA                                  0
# patient_state_CO                                  0
# patient_state_CT                                  0
# patient_state_DC                                  0
# patient_state_DE                                  0
# patient_state_FL                                  0
# patient_state_GA                                  0
# patient_state_HI                                  0
# patient_state_IA                                  0
# patient_state_ID                                  0
# patient_state_IL                                  0
# patient_state_IN                                  0
# patient_state_KS                                  0
# patient_state_KY                                  0
# patient_state_LA                                  0
# patient_state_MA                                  0
# patient_state_MD                                  0
# patient_state_MI                                  0
# patient_state_MN                                  0
# patient_state_MO                                  0
# patient_state_MS                                  0
# patient_state_MT                                  0
# patient_state_NC                                  0
# patient_state_ND                                  0
# patient_state_NE                                  0
# patient_state_NH                                  0
# patient_state_NJ                                  0
# patient_state_NM                                  0
# patient_state_NV                                  0
# patient_state_NY                                  0
# patient_state_OH                                  0
# patient_state_OK                                  0
# patient_state_OR                                  0
# patient_state_PA                                  0
# patient_state_PR                                  0
# patient_state_RI                                  0
# patient_state_SC                                  0
# patient_state_SD                                  0
# patient_state_TN                                  0
# patient_state_TX                                  0
# patient_state_UT                                  0
# patient_state_VA                                  0
# patient_state_WA                                  0
# patient_state_WI                                  0
# patient_state_WV                                  0
# patient_state_WY                                  0
# location_category_Central Portion                 0
# location_category_General Breast Cancer           0
# location_category_Lower-Inner Quadrant            0
# location_category_Lower-Outer Quadrant            0
# location_category_Nipple and Areola               0
# location_category_Overlapping Sites               0
# location_category_Secondary Malignant Neoplasm    0
# location_category_Unspecified Site                0
# location_category_Upper-Inner Quadrant            0
# location_category_Upper-Outer Quadrant            0
# dtype: int64

# %%
# look at features again
numerical_columns = train.select_dtypes(include=['float64', 'int64']).columns

categorical_feature = 'DiagPeriodL90D'
categories = train_clean[categorical_feature].unique()
colors = ['red', 'blue']

n_columns = 4  
n_rows = int(np.ceil(len(numerical_columns) / n_columns))

plt.figure(figsize=(15, 5 * n_rows)) 

for i, col in enumerate(numerical_columns, start=1):
    plt.subplot(n_rows, n_columns, i)  
    for j, category in enumerate(categories):
        category_data = train[train[categorical_feature] == category]
        plt.hist(category_data[col], bins=20, color=colors[j], alpha=0.5, label=f'Category {category}')
    
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.title(col)
    plt.legend()
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Preprocessing (Testing)

# %%
test_clean=test.copy()

# %%
test.shape
# Out:
# (5792, 82)

# %%
test.describe()
# Out:
#           patient_id  patient_zip3  patient_age          bmi    population  \
# count    5792.000000   5792.000000  5792.000000  1777.000000   5792.000000
# mean   549946.787983    570.217887    59.274862    28.900073  20266.872152
# std    260988.833446    275.314510    13.076323     5.609491  13694.738314
# min    100266.000000    101.000000    18.000000    14.000000    829.515152
# 25%    320284.500000    329.000000    50.000000    24.600000   8863.550000
# 50%    553042.000000    554.000000    59.000000    28.150000  18711.016665
# 75%    778552.250000    836.000000    67.000000    32.860000  28996.772730
# max    999890.000000    996.000000    91.000000    43.900000  71374.131580
#
#             density   age_median  age_under_10  age_10_to_19      age_20s  \
# count   5792.000000  5792.000000   5792.000000   5792.000000  5792.000000
# mean    1510.471786    40.575472     11.119250     12.919191    13.218348
# std     2883.409750     4.029852      1.478579      1.909698     3.294389
# min        0.821739    20.600000      0.000000      6.314286     5.925000
# 25%      161.925000    37.190476     10.160000     11.726471    10.996226
# 50%      626.236667    40.640909     11.039216     12.923944    12.531646
# 75%     1612.851111    43.085938     12.143396     13.904830    14.937500
# max    21172.000000    54.570000     16.481818     35.300000    62.100000
#
#            age_30s      age_40s      age_50s      age_60s      age_70s  \
# count  5792.000000  5792.000000  5792.000000  5792.000000  5792.000000
# mean     12.841374    12.063877    13.445992    12.669871     7.708020
# std       2.358636     1.250266     1.607599     2.584994     2.172747
# min       1.500000     0.800000     0.000000     0.200000     0.000000
# 25%      11.211818    11.354237    12.304615    10.642553     6.010527
# 50%      12.404348    12.118605    13.572990    12.535714     7.380952
# 75%      14.037838    12.867171    14.540741    14.091549     8.934848
# max      25.471429    17.820000    21.661111    26.457895    16.270833
#
#        age_over_80         male       female      married     divorced  \
# count  5792.000000  5792.000000  5792.000000  5792.000000  5792.000000
# mean      4.013545    50.101101    49.898977    47.785025    12.741028
# std       1.240229     1.667512     1.667478     7.449499     2.050688
# min       0.000000    39.725000    38.400000     0.900000     0.200000
# 25%       3.284615    49.257353    49.081395    42.989464    11.220536
# 50%       3.814044    49.989744    50.010256    49.665574    12.800000
# 75%       4.556897    50.918605    50.742647    52.994340    14.200000
# max      18.825000    61.600000    60.275000    62.697368    21.033333
#
#        never_married      widowed  family_size  family_dual_income  \
# count    5792.000000  5792.000000  5791.000000         5791.000000
# mean       33.603883     5.869018     3.200133           51.743661
# std         8.028668     1.553876     0.225862            6.783944
# min        18.294444     0.000000     2.550370           26.714286
# 25%        27.201818     4.766154     3.036364           47.525926
# 50%        31.928889     5.572549     3.164286           52.343333
# 75%        38.642623     6.708621     3.332055           56.190385
# max        98.900000    20.650000     4.172273           70.925000
#
#        income_household_median  income_household_under_5  \
# count              5791.000000               5791.000000
# mean              73804.632684                  3.272925
# std               20512.986299                  1.447294
# min               32935.384620                  0.750000
# 25%               60952.268290                  2.265217
# 50%               69407.350000                  2.851429
# 75%               82486.027030                  4.010526
# max              164119.176500                 19.620000
#
#        income_household_5_to_10  income_household_10_to_15  \
# count               5791.000000                5791.000000
# mean                   2.521034                   4.176442
# std                    1.318399                   1.752962
# min                    0.361538                   1.093750
# 25%                    1.536364                   2.897826
# 50%                    2.198571                   3.807895
# 75%                    3.112791                   5.190625
# max                   11.872222                  14.277778
#
#        income_household_15_to_20  income_household_20_to_25  \
# count                5791.000000                5791.000000
# mean                    3.957638                   4.097660
# std                     1.450724                   1.325385
# min                     1.027778                   1.100000
# 25%                     2.933939                   3.173913
# 50%                     3.795238                   4.059091
# 75%                     4.687500                   4.877083
# max                    12.400000                  10.403226
#
#        income_household_25_to_35  income_household_35_to_50  \
# count                5791.000000                5791.000000
# mean                    8.445731                  11.602190
# std                     2.203642                   2.517627
# min                     2.794595                   1.700000
# 25%                     7.035294                   9.990909
# 50%                     8.487838                  11.833333
# 75%                     9.918182                  13.334524
# max                    18.340000                  24.075000
#
#        income_household_50_to_75  income_household_75_to_100  \
# count                5791.000000                 5791.000000
# mean                   17.001494                   12.703247
# std                     2.701921                    1.803451
# min                     4.950000                    4.733333
# 25%                    15.415254                   11.397872
# 50%                    17.112500                   12.700000
# 75%                    18.600000                   13.964286
# max                    27.130303                   24.800000
#
#        income_household_100_to_150  income_household_150_over  \
# count                  5791.000000                5791.000000
# mean                     15.791220                  16.429361
# std                       3.165370                   8.850360
# min                       4.288889                   1.194118
# 25%                      13.618605                   9.915362
# 50%                      15.955769                  14.631915
# 75%                      18.408889                  20.935714
# max                      31.325000                  52.823529
#
#        income_household_six_figure  income_individual_median  home_ownership  \
# count                  5791.000000               5792.000000     5791.000000
# mean                     32.220581              36305.093443       66.346768
# std                      11.005963               8160.726716       14.000678
# min                       5.692593               4316.000000       15.850000
# 25%                      24.396667              31232.794870       56.714286
# 50%                      30.522807              34915.324320       70.249057
# 75%                      38.235000              39698.466670       77.216216
# max                      69.032353              88910.500000       90.366667
#
#        housing_units    home_value  rent_median  rent_burden  \
# count    5792.000000  5.791000e+03  5791.000000  5791.000000
# mean     7408.864278  3.331960e+05  1223.874116    31.285106
# std      4860.167800  2.500832e+05   425.301686     4.941503
# min         0.000000  6.062900e+04   448.400000    16.692308
# 25%      3284.571429  1.655080e+05   883.723684    28.147826
# 50%      6805.250000  2.383431e+05  1136.808511    30.828571
# 75%     10825.825000  4.033836e+05  1478.241935    33.720000
# max     25922.552630  1.853109e+06  2965.250000   108.600000
#
#        education_less_highschool  education_highschool  \
# count                5792.000000           5792.000000
# mean                   12.027330             27.885383
# std                     5.053325              8.017430
# min                     0.000000              0.000000
# 25%                     8.400000             21.637209
# 50%                    10.844444             27.560882
# 75%                    15.316667             33.787719
# max                    34.325424             53.960000
#
#        education_some_college  education_bachelors  education_graduate  \
# count             5792.000000          5792.000000         5792.000000
# mean                28.983067            19.060371           12.044722
# std                  4.901240             6.193795            5.879815
# min                  7.200000             3.666667            3.094340
# 25%                 26.090741            13.956962            7.522222
# 50%                 29.363043            18.829167           10.525891
# 75%                 32.368333            23.739394           15.551351
# max                 50.133333            41.700000           51.840000
#
#        education_college_or_above  education_stem_degree  \
# count                 5792.000000            5792.000000
# mean                    31.105093              43.299536
# std                     11.597326               4.631933
# min                      7.888889              27.147826
# 25%                     21.722785              40.134426
# 50%                     29.775000              43.021212
# 75%                     38.552965              46.208696
# max                     77.816667              73.000000
#
#        labor_force_participation  unemployment_rate  self_employed  \
# count                5792.000000        5792.000000    5791.000000
# mean                   61.515629           5.924224      13.144907
# std                     5.998048           1.891790       3.407495
# min                    30.700000           1.131579       3.096774
# 25%                    57.864706           4.674419      10.873810
# 50%                    62.406494           5.474138      12.730435
# 75%                    65.668831           6.862868      15.009302
# max                    75.385714          18.800000      25.537500
#
#             farmer   race_white   race_black   race_asian  race_native  \
# count  5791.000000  5792.000000  5792.000000  5792.000000  5792.000000
# mean      2.002827    70.082777    11.437775     5.262948     0.945075
# std       3.271179    17.945750    12.615989     6.569992     2.681518
# min       0.000000    14.495652     0.096429     0.000000     0.000000
# 25%       0.049444    57.224444     2.172222     0.986957     0.212857
# 50%       0.513636    70.939130     6.410256     2.686957     0.430952
# 75%       2.484000    85.854762    16.269444     6.638462     0.790000
# max      26.729412    98.443750    69.660000    49.850000    76.934783
#
#        race_pacific   race_other  race_multiple     hispanic     disabled  \
# count   5792.000000  5792.000000    5792.000000  5792.000000  5792.000000
# mean       0.148971     5.555768       6.566156    18.036444    13.483574
# std        0.670291     6.142503       3.552653    16.716396     3.693358
# min        0.000000     0.002564       0.706250     0.194444     4.600000
# 25%        0.024138     1.314085       3.820000     4.698529    10.388889
# 50%        0.053125     3.510811       5.658065    11.842623    13.093333
# 75%        0.146154     7.848214       8.850769    27.594872    15.802128
# max       14.758442    33.188889      26.429870    91.005085    35.155556
#
#            poverty  limited_english  commute_time  health_uninsured  \
# count  5791.000000      5791.000000   5792.000000       5792.000000
# mean     13.435855         4.292997     27.915686          8.636586
# std       5.105505         4.673928      4.997893          4.142770
# min       3.433333         0.000000     13.722078          2.440000
# 25%       9.995000         0.878049     24.932500          5.772727
# 50%      12.218182         2.690196     27.561905          7.468000
# 75%      16.444444         5.863830     30.709375         10.820000
# max      38.347826        22.591667     48.020000         27.566102
#
#            veteran        Ozone         PM25          N02
# count  5792.000000  5778.000000  5778.000000  5778.000000
# mean      7.171897    39.788771     7.435363    15.936645
# std       3.107104     3.486773     1.528655     5.894659
# min       1.200000    30.939316     2.636008     2.760371
# 25%       5.078571    37.722740     6.590523    11.100666
# 50%       7.070370    39.127948     7.666953    15.246437
# 75%       8.774510    41.075217     8.276922    20.348878
# max      21.426667    52.237210    11.169408    31.504775

# %%
# adjust the age ranges 

# defining bins and labels for age ranges
age_bins = [0, 19, 39, 59, 69, float('inf')]  # Define bins
age_labels = ['19 and Under', '20-39', '40-59', '60-69', 'Over 70']

test_clean['age_group'] = pd.cut(test_clean['patient_age'], bins=age_bins, labels=age_labels, right=True)
age_dummies = pd.get_dummies(test_clean['age_group'], prefix='age')

test_clean = pd.concat([test_clean, age_dummies], axis=1)

print(test_clean[['patient_age'] + list(age_dummies.columns)].head())
# Out:
#    patient_age  age_19 and Under  age_20-39  age_40-59  age_60-69  age_Over 70
# 0           54             False      False       True      False        False
# 1           52             False      False       True      False        False
# 2           61             False      False      False       True        False
# 3           64             False      False      False       True        False
# 4           40             False      False       True      False        False

# %%
test_clean['location_category'] = test_clean['breast_cancer_diagnosis_desc'].apply(categorize_location)

print(test_clean[['breast_cancer_diagnosis_desc', 'location_category']].head())
# Out:
#                         breast_cancer_diagnosis_desc      location_category
# 0  Malig neoplasm of upper-outer quadrant of left...   Upper-Outer Quadrant
# 1  Malignant neoplasm of unspecified site of left...       Unspecified Site
# 2  Malignant neoplasm of unsp site of right femal...  General Breast Cancer
# 3  Malignant neoplasm of unspecified site of left...       Unspecified Site
# 4  Malig neoplasm of upper-outer quadrant of left...   Upper-Outer Quadrant

# %%
# Replacing missing values in patient_race column with 'prefer not to answer'

test_clean['patient_race'] = test_clean['patient_race'].fillna('Prefer Not to Answer')

print(test_clean['patient_race'].value_counts())
# Out:
# patient_race
# Prefer Not to Answer    2901
# White                   1606
# Black                    510
# Hispanic                 347
# Other                    273
# Asian                    155
# Name: count, dtype: int64

# %%
# BMI

# Grouping by age, race, and location to compute the mean BMI for each subgroup
## This will hopefully eliminate biases in the data (fingers crossed)

bmi_means = test_clean.groupby(['age_group', 'patient_race', 'patient_state'])['bmi'].mean().reset_index()
bmi_means.rename(columns={'bmi': 'mean_bmi'}, inplace=True)

test_clean = test_clean.merge(bmi_means, on=['age_group', 'patient_race', 'patient_state'], how='left')

test_clean['bmi'] = test_clean['bmi'].fillna(test_clean['mean_bmi'])


print(test_clean['bmi'].describe())
# Out:
# count    5395.000000
# mean       28.846620
# std         4.002655
# min        14.000000
# 25%        27.000000
# 50%        28.660000
# 75%        30.652381
# max        43.900000
# Name: bmi, dtype: float64

# %%
# Replacing missing values in payer_type column with 'prefer not to answer'

test_clean['payer_type'] = test_clean['payer_type'].fillna('Prefer Not to Answer')

print(test_clean['payer_type'].value_counts())
# Out:
# payer_type
# COMMERCIAL              2759
# MEDICARE ADVANTAGE      1151
# MEDICAID                1122
# Prefer Not to Answer     760
# Name: count, dtype: int64

# %%
# One-hot encode the 'location_category' column
test_clean = pd.get_dummies(test_clean, columns=['location_category'], drop_first=True)

# One-hot encode the 'patient_state' column
test_clean = pd.get_dummies(test_clean, columns=['patient_state'], drop_first=True)

# %%
# initial removal of columns I deem unnecesarry

test_clean=test_clean.drop(["education_less_highschool", "education_highschool","education_some_college","education_bachelors",
                              "education_graduate","education_college_or_above","education_stem_degree","married","divorced",
                              "never_married","widowed", "age_median",'breast_cancer_diagnosis_desc','age_under_10','age_10_to_19','age_20s','age_30s',
                         'age_30s','age_40s','age_50s','age_60s','age_70s','age_over_80','patient_age','patient_race',
                         'patient_gender','breast_cancer_diagnosis_code','breast_cancer_diagnosis_code',
                          'metastatic_cancer_diagnosis_code','metastatic_first_novel_treatment','metastatic_first_novel_treatment_type',
                         'Region','Division','labor_force_participation','unemployment_rate','self_employed','farmer','family_size','payer_type'], axis=1)

# %%
# drop rows from all columns that now have less than 500 missing values
columns_to_drop_missing = test_clean.columns[test_clean.isnull().sum() < 500]

test_clean = test_clean.dropna(subset=columns_to_drop_missing)

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
print(test_clean.isnull().sum())
# Out:
# patient_id                                        0
# patient_zip3                                      0
# bmi                                               0
# population                                        0
# density                                           0
# male                                              0
# female                                            0
# family_dual_income                                0
# income_household_median                           0
# income_household_under_5                          0
# income_household_5_to_10                          0
# income_household_10_to_15                         0
# income_household_15_to_20                         0
# income_household_20_to_25                         0
# income_household_25_to_35                         0
# income_household_35_to_50                         0
# income_household_50_to_75                         0
# income_household_75_to_100                        0
# income_household_100_to_150                       0
# income_household_150_over                         0
# income_household_six_figure                       0
# income_individual_median                          0
# home_ownership                                    0
# housing_units                                     0
# home_value                                        0
# rent_median                                       0
# rent_burden                                       0
# race_white                                        0
# race_black                                        0
# race_asian                                        0
# race_native                                       0
# race_pacific                                      0
# race_other                                        0
# race_multiple                                     0
# hispanic                                          0
# disabled                                          0
# poverty                                           0
# limited_english                                   0
# commute_time                                      0
# health_uninsured                                  0
# veteran                                           0
# Ozone                                             0
# PM25                                              0
# N02                                               0
# age_group                                         0
# age_19 and Under                                  0
# age_20-39                                         0
# age_40-59                                         0
# age_60-69                                         0
# age_Over 70                                       0
# mean_bmi                                          0
# location_category_Central Portion                 0
# location_category_General Breast Cancer           0
# location_category_Lower-Inner Quadrant            0
# location_category_Lower-Outer Quadrant            0
# location_category_Nipple and Areola               0
# location_category_Overlapping Sites               0
# location_category_Secondary Malignant Neoplasm    0
# location_category_Unspecified Site                0
# location_category_Upper-Inner Quadrant            0
# location_category_Upper-Outer Quadrant            0
# patient_state_AL                                  0
# patient_state_AR                                  0
# patient_state_AZ                                  0
# patient_state_CA                                  0
# patient_state_CO                                  0
# patient_state_DC                                  0
# patient_state_DE                                  0
# patient_state_FL                                  0
# patient_state_GA                                  0
# patient_state_HI                                  0
# patient_state_IA                                  0
# patient_state_ID                                  0
# patient_state_IL                                  0
# patient_state_IN                                  0
# patient_state_KS                                  0
# patient_state_KY                                  0
# patient_state_LA                                  0
# patient_state_MA                                  0
# patient_state_MD                                  0
# patient_state_MI                                  0
# patient_state_MN                                  0
# patient_state_MO                                  0
# patient_state_MS                                  0
# patient_state_MT                                  0
# patient_state_NC                                  0
# patient_state_ND                                  0
# patient_state_NE                                  0
# patient_state_NJ                                  0
# patient_state_NM                                  0
# patient_state_NV                                  0
# patient_state_NY                                  0
# patient_state_OH                                  0
# patient_state_OK                                  0
# patient_state_OR                                  0
# patient_state_PA                                  0
# patient_state_SC                                  0
# patient_state_SD                                  0
# patient_state_TN                                  0
# patient_state_TX                                  0
# patient_state_UT                                  0
# patient_state_VA                                  0
# patient_state_WA                                  0
# patient_state_WI                                  0
# patient_state_WV                                  0
# patient_state_WY                                  0
# dtype: int64

# %%
# Save the clean datasets as a CSV file
train_clean.to_csv('train_preprocessed.csv', index=False)
test_clean.to_csv('test_preprocessed.csv', index=False)
